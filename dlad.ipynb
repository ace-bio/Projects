# %% [markdown]
# <a href="https://colab.research.google.com/github/ace-bio/Projects/blob/main/dlad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
from nipype.interfaces.fsl.maths import UnaryMaths
from nipype.interfaces.fsl import MultiImageMaths
from nilearn import datasets, plotting
from nltools.data import Brain_Data
from nilearn import datasets
from nilearn import plotting
from nilearn.image import load_img
from nltools.mask import expand_mask, collapse_mask
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import nibabel as nib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-0ea97204de7f> in <cell line: 3>()
#       1 import pandas as pd
#       2 import os
# ----> 3 from nipype.interfaces.fsl.maths import UnaryMaths
#       4 from nipype.interfaces.fsl import MultiImageMaths
#       5 from nilearn import datasets, plotting
#
# ModuleNotFoundError: No module named 'nipype'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Getting the dataset

# %%
dt = np.load("005_S_0610_ses-20070809_mod-T1w_brain-1mm-cw.npz")
img = dt["data"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-18f7bbfa8a82> in <cell line: 1>()
# ----> 1 dt = np.load("005_S_0610_ses-20070809_mod-T1w_brain-1mm-cw.npz")
#       2 img = dt["data"]
#
# NameError: name 'np' is not defined

# %%
img_data = nib.Nifti1Image(img,np.eye(4))

# %%
plotting.plot_anat(img_data)

# %%
test= img_data.get_fdata()

# %%
test.shape
# Out:
# (192, 192, 192)
